# %% [markdown]
# <a href="https://colab.research.google.com/github/Haritachi/Code-with-hari/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

data = pd.read_csv('data.csv')

model = LinearRegression()
model.fit(X = data['year'].values.reshape(-1, 1), y = data['price'].values.reshape(-1, 1))

model.predict([[2005]])

plt.scatter(x= data['year'], y = data['price'])
plt.plot(data['year'], model.predict(data['year'].values.reshape(-1, 1)), color = 'red')
